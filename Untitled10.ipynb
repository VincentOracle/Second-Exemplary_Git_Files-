# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
# Load the dataset
df = pd.read_excel('C://Users//n//Downloads//churn2.xls')
df.head()
# Out:
#   COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 0    zero   31953        0         6  313378            161
# 1     one   36147        0        13  800586            244
# 2     one   27273      230         0  305049            201
# 3    zero  120070       38        33  788235            780
# 4     one   29215      208        85  224784            241
#
#    OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION REPORTED_SATISFACTION  \
# 0                            0                      4                 unsat
# 1                            0                      6                 unsat
# 2                           16                     15                 unsat
# 3                            3                      2                 unsat
# 4                           21                      1            very_unsat
#
#   REPORTED_USAGE_LEVEL CONSIDERING_CHANGE_OF_PLAN  LEAVE
# 0               little                         no   STAY
# ...

# %%
# Encode categorical variables (assuming 'COLLEGE' and 'CONSIDERING_CHANGE_OF_PLAN' are categorical)
df_encoded = pd.get_dummies(df, columns=['COLLEGE', 'CONSIDERING_CHANGE_OF_PLAN','REPORTED_SATISFACTION','REPORTED_USAGE_LEVEL','CONSIDERING_CHANGE_OF_PLAN','LEAVE'])

# Split the data into features (X) and the target (y)
X = df_encoded.drop(columns=['INCOME'])  # Adjust columns if necessary
y = df_encoded['INCOME']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Build a Decision Tree model
dt_model = DecisionTreeClassifier()
dt_scores = cross_val_score(dt_model, X_train, y_train, cv=5, scoring='accuracy')  # Use 5-fold CV

# Build a Logistic Regression model
lr_model = LogisticRegression()
lr_scores = cross_val_score(lr_model, X_train, y_train, cv=5, scoring='accuracy')  # Use 5-fold CV

# Calculate average accuracy and standard deviation
avg_accuracy_dt = dt_scores.mean()
std_accuracy_dt = dt_scores.std()
avg_accuracy_lr = lr_scores.mean()
std_accuracy_lr = lr_scores.std()

# Report accuracy for each fold
for i, (dt_score, lr_score) in enumerate(zip(dt_scores, lr_scores), start=1):
    print(f"Fold {i}: Decision Tree Accuracy = {dt_score:.2f}, Logistic Regression Accuracy = {lr_score:.2f}")

# Report average accuracy and standard deviation
print(f"Average Accuracy (Decision Tree): {avg_accuracy_dt:.2f}")
print(f"Standard Deviation (Decision Tree): {std_accuracy_dt:.2f}")
print(f"Average Accuracy (Logistic Regression): {avg_accuracy_lr:.2f}")
print(f"Standard Deviation (Logistic Regression): {std_accuracy_lr:.2f}")

# Now, you can proceed with creating Jupyter notebook PDFs and defining benefit/cost values.
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:822, in Parallel.dispatch_one_batch(self, iterator)
#     821 try:
# --> 822     tasks = self._ready_batches.get(block=False)
#     823 except queue.Empty:
#     824     # slice the iterator n_jobs * batchsize items at a time. If the
#     825     # slice returns less than that, then the current batchsize puts
#    (...)
#     828     # accordingly to distribute evenly the last items between all
#     829     # workers.
#
# File ~\anaconda3\lib\queue.py:168, in Queue.get(self, block, timeout)
#     167     if not self._qsize():
# --> 168         raise Empty
#     169 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
# Encode categorical variables (assuming 'COLLEGE' and 'CONSIDERING_CHANGE_OF_PLAN' are categorical)
df_encoded = pd.get_dummies(df, columns=['COLLEGE', 'CONSIDERING_CHANGE_OF_PLAN','REPORTED_SATISFACTION','REPORTED_USAGE_LEVEL','CONSIDERING_CHANGE_OF_PLAN','LEAVE'])

# Split the data into features (X) and the target (y)
X = df_encoded.drop(columns=['INCOME'])  # Adjust columns if necessary
y = df_encoded['INCOME']

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Build a Decision Tree model
dt_model = DecisionTreeClassifier()
dt_scores = cross_val_score(dt_model, X_train, y_train, cv=10, scoring='accuracy')
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:822, in Parallel.dispatch_one_batch(self, iterator)
#     821 try:
# --> 822     tasks = self._ready_batches.get(block=False)
#     823 except queue.Empty:
#     824     # slice the iterator n_jobs * batchsize items at a time. If the
#     825     # slice returns less than that, then the current batchsize puts
#    (...)
#     828     # accordingly to distribute evenly the last items between all
#     829     # workers.
#
# File ~\anaconda3\lib\queue.py:168, in Queue.get(self, block, timeout)
#     167     if not self._qsize():
# --> 168         raise Empty
#     169 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
# Build a Logistic Regression model
lr_model = LogisticRegression()
lr_scores = cross_val_score(lr_model, X_train, y_train, cv=10, scoring='accuracy')

# Calculate average accuracy and standard deviation
avg_accuracy_dt = dt_scores.mean()
std_accuracy_dt = dt_scores.std()
avg_accuracy_lr = lr_scores.mean()
std_accuracy_lr = lr_scores.std()

# Report accuracy for each fold
for i, (dt_score, lr_score) in enumerate(zip(dt_scores, lr_scores), start=1):
    print(f"Fold {i}: Decision Tree Accuracy = {dt_score:.2f}, Logistic Regression Accuracy = {lr_score:.2f}")

# Report average accuracy and standard deviation
print(f"Average Accuracy (Decision Tree): {avg_accuracy_dt:.2f}")
print(f"Standard Deviation (Decision Tree): {std_accuracy_dt:.2f}")
print(f"Average Accuracy (Logistic Regression): {avg_accuracy_lr:.2f}")
print(f"Standard Deviation (Logistic Regression): {std_accuracy_lr:.2f}")

# Now, you can proceed with creating Jupyter notebook PDFs and defining benefit/cost values.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 5>()
#       2 df_encoded = pd.get_dummies(df, columns=['COLLEGE', 'CONSIDERING_CHANGE_OF_PLAN','REPORTED_SATISFACTION','REPORTED_USAGE_LEVEL','CONSIDERING_CHANGE_OF_PLAN','LEAVE'], drop_first=False)
#       4 # Split the data into features (X) and the target (y)
# ----> 5 X = df_encoded.drop(columns=['LEAVE'])  # Adjust columns if necessary
#       6 y = df_encoded['LEAVE']
#       8 # Split the data into training and test sets
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# ...

# %%
# Split the data into features (X) and the target (y)
X = df.drop(columns=['LEAVE'])  # Adjust columns if necessary
y = df['LEAVE']

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Build a Decision Tree model
dt_model = DecisionTreeClassifier()
dt_scores = cross_val_score(dt_model, X_train, y_train, cv=10, scoring='accuracy')
# Out:
# C:\Users\n\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 10.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\n\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\n\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\n\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 165, in fit
#     X, y = self._validate_data(
# ...

# %%
# Build a Logistic Regression model
lr_model = LogisticRegression()
lr_scores = cross_val_score(lr_model, X_train, y_train, cv=10, scoring='accuracy')

# Calculate average accuracy and standard deviation
avg_accuracy_dt = dt_scores.mean()
std_accuracy_dt = dt_scores.std()
avg_accuracy_lr = lr_scores.mean()
std_accuracy_lr = lr_scores.std()

# Report accuracy for each fold
for i, (dt_score, lr_score) in enumerate(zip(dt_scores, lr_scores), start=1):
    print(f"Fold {i}: Decision Tree Accuracy = {dt_score:.2f}, Logistic Regression Accuracy = {lr_score:.2f}")

# Report average accuracy and standard deviation
print(f"Average Accuracy (Decision Tree): {avg_accuracy_dt:.2f}")
print(f"Standard Deviation (Decision Tree): {std_accuracy_dt:.2f}")
print(f"Average Accuracy (Logistic Regression): {avg_accuracy_lr:.2f}")
print(f"Standard Deviation (Logistic Regression): {std_accuracy_lr:.2f}")

# Now, you can proceed with creating Jupyter notebook PDFs and defining benefit/cost values.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# Load the TelCo CHURN dataset
data = pd.read_excel('C://Users//n//Downloads//churn2.xls')

# Divide the data into training and test sets (75% training, 25% test)
X = data.drop(columns=['LEAVE'])
y = data['LEAVE']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Build Decision Tree and Logistic Regression models
dt_model = DecisionTreeClassifier()
lr_model = LogisticRegression()

# Perform 10-fold cross-validation
dt_scores = cross_val_score(dt_model, X_train, y_train, cv=10, scoring='accuracy')
lr_scores = cross_val_score(lr_model, X_train, y_train, cv=10, scoring='accuracy')

# Calculate average accuracy and standard deviation
avg_accuracy_dt = dt_scores.mean()
std_accuracy_dt = dt_scores.std()
avg_accuracy_lr = lr_scores.mean()
std_accuracy_lr = lr_scores.std()

# Report accuracy for each fold
for i in range(10):
    print(f"Fold {i + 1}: Decision Tree Accuracy = {dt_scores[i]:.2f}, Logistic Regression Accuracy = {lr_scores[i]:.2f}")

# Report average accuracy and standard deviation
print("Average Accuracy (Decision Tree):", avg_accuracy_dt)
print("Standard Deviation (Decision Tree):", std_accuracy_dt)
print("Average Accuracy (Logistic Regression):", avg_accuracy_lr)
print("Standard Deviation (Logistic Regression):", std_accuracy_lr)
# Out:
# Fold 1: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 2: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 3: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 4: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 5: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 6: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 7: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 8: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 9: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 10: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Average Accuracy (Decision Tree): nan
# Standard Deviation (Decision Tree): nan
# Average Accuracy (Logistic Regression): nan
# Standard Deviation (Logistic Regression): nan
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# Load the TelCo CHURN dataset
data = pd.read_excel('C://Users//n//Downloads//churn2.xls')

# Data preprocessing
label_encoder = LabelEncoder()
data['LEAVE'] = label_encoder.fit_transform(data['LEAVE'])
# Perform one-hot encoding or label encoding for other categorical variables if needed

# Divide the data into training and test sets (75% training, 25% test)
X = data.drop(columns=['LEAVE'])
y = data['LEAVE']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Build Decision Tree and Logistic Regression models
dt_model = DecisionTreeClassifier()
lr_model = LogisticRegression()

# Perform 10-fold cross-validation
dt_scores = cross_val_score(dt_model, X_train, y_train, cv=10, scoring='accuracy')
lr_scores = cross_val_score(lr_model, X_train, y_train, cv=10, scoring='accuracy')

# Calculate average accuracy and standard deviation
avg_accuracy_dt = dt_scores.mean()
std_accuracy_dt = dt_scores.std()
avg_accuracy_lr = lr_scores.mean()
std_accuracy_lr = lr_scores.std()

# Report accuracy for each fold
for i in range(10):
    print(f"Fold {i + 1}: Decision Tree Accuracy = {dt_scores[i]:.2f}, Logistic Regression Accuracy = {lr_scores[i]:.2f}")

# Report average accuracy and standard deviation
print("Average Accuracy (Decision Tree):", avg_accuracy_dt)
print("Standard Deviation (Decision Tree):", std_accuracy_dt)
print("Average Accuracy (Logistic Regression):", avg_accuracy_lr)
print("Standard Deviation (Logistic Regression):", std_accuracy_lr)
# Out:
# Fold 1: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 2: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 3: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 4: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 5: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 6: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 7: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 8: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 9: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 10: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Average Accuracy (Decision Tree): nan
# Standard Deviation (Decision Tree): nan
# Average Accuracy (Logistic Regression): nan
# Standard Deviation (Logistic Regression): nan
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# Load the TelCo CHURN dataset
df = pd.read_excel('C://Users//n//Downloads//churn2.xls')

# Data preprocessing
label_encoder = LabelEncoder()
data['LEAVE'] = label_encoder.fit_transform(data['LEAVE'])
# Perform one-hot encoding or label encoding for other categorical variables if needed

# Divide the data into training and test sets (75% training, 25% test)
X = data.drop(columns=['LEAVE'])
y = data['LEAVE']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Build Decision Tree and Logistic Regression models
dt_model = DecisionTreeClassifier()
lr_model = LogisticRegression()

# Perform 10-fold cross-validation
dt_scores = cross_val_score(dt_model, X_train, y_train, cv=10, scoring='accuracy')
lr_scores = cross_val_score(lr_model, X_train, y_train, cv=10, scoring='accuracy')

# Calculate average accuracy and standard deviation
avg_accuracy_dt = dt_scores.mean()
std_accuracy_dt = dt_scores.std()
avg_accuracy_lr = lr_scores.mean()
std_accuracy_lr = lr_scores.std()

# Report accuracy for each fold
for i in range(10):
    print(f"Fold {i + 1}: Decision Tree Accuracy = {dt_scores[i]:.2f}, Logistic Regression Accuracy = {lr_scores[i]:.2f}")

# Report average accuracy and standard deviation
print("Average Accuracy (Decision Tree):", avg_accuracy_dt)
print("Standard Deviation (Decision Tree):", std_accuracy_dt)
print("Average Accuracy (Logistic Regression):", avg_accuracy_lr)
print("Standard Deviation (Logistic Regression):", std_accuracy_lr)
# Out:
# Fold 1: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 2: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 3: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 4: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 5: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 6: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 7: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 8: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 9: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Fold 10: Decision Tree Accuracy = nan, Logistic Regression Accuracy = nan
# Average Accuracy (Decision Tree): nan
# Standard Deviation (Decision Tree): nan
# Average Accuracy (Logistic Regression): nan
# Standard Deviation (Logistic Regression): nan
# ...
